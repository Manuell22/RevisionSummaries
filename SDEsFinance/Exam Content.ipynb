# %% [markdown]
# === SDEs in Finance ===
# No problem on Numerical Methods
#
# No problem on Girsanov's theorem
#
# No problem on Feynman-Kac formula
#
# No problem in different convergences (probability, law...)
#
# HOWEVER they are useful for later in career in quant. Can read them later on the job.
#
# Exam structure
#
# Q1 - SDEs (mocks Q1)
#
# Q2 - Option pricing (mocks Q2 or Q3)
#
# Q3 - Risk (mocks Q4)
#
# Q4 (mastery) - Mixture dynamics (see lecture notes)
